# %%
import matplotlib.pyplot as plt
import json

plt.figure( figsize=(20,5))

plt.subplot(1,2,1)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_ra.dat').read()
data_ra = json.loads(f)

plt.hist(data_ra, bins = 100) 
plt.xlabel("RA position difference in arcsec")
plt.ylabel("# of sources")


plt.subplot(1,2,2)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_dec.dat').read()
data_dec = json.loads(f)

plt.hist(data_dec, bins = 100) 
plt.xlabel("Dec position difference in arcsec")
plt.ylabel("# of sources")
#plt.ticklabel_format(style='sci', axis='x',scilimits=(0,0))

plt.show()

# %%
dists= np.sqrt(np.power(data_ra,2)+np.power(data_dec,2))

plt.hist(dists, bins = 100) 
plt.xlabel("position difference in arcsec")
plt.ylabel("# of sources")

# %%
import matplotlib.pyplot as plt
import json

plt.figure( figsize=(20,5))

plt.subplot(1,2,1)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_ra_complete.dat').read()
data_ra = json.loads(f)

plt.hist(data_ra, bins = 100) 
plt.xlabel("RA position difference in arcsec")
plt.ylabel("# of sources")


plt.subplot(1,2,2)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_dec_complete.dat').read()
data_dec = json.loads(f)

plt.hist(data_dec, bins = 100) 
plt.xlabel("Dec position difference in arcsec")
plt.ylabel("# of sources")
#plt.ticklabel_format(style='sci', axis='x',scilimits=(0,0))

plt.show()

# %%
dists= np.sqrt(np.power(data_ra,2)+np.power(data_dec,2))

plt.hist(dists, bins = 100) 
plt.xlabel("position difference in arcsec")
plt.ylabel("# of sources")

# %% [markdown]
# # Dispersion for complete jointcal coadds of 7 days

# %%
plt.figure( figsize=(20,5))

plt.subplot(1,2,1)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_ra_comp6days.dat').read()
data_ra = json.loads(f)

plt.hist(data_ra, bins = 100) 
plt.xlabel("RA position difference in arcsec")
plt.ylabel("# of sources")


plt.subplot(1,2,2)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_dec_comp6days.dat').read()
data_dec = json.loads(f)

plt.hist(data_dec, bins = 100) 
plt.xlabel("Dec position difference in arcsec")
plt.ylabel("# of sources")
#plt.ticklabel_format(style='sci', axis='x',scilimits=(0,0))

plt.show()

# %%
dists= np.sqrt(np.power(data_ra,2)+np.power(data_dec,2))

plt.hist(dists, bins = 100) 
plt.xlabel("position difference in arcsec")
plt.ylabel("# of sources")

# %% [markdown]
# # Dispersion for independent jointcal coadds of 7 days

# %%
plt.figure( figsize=(20,5))

plt.subplot(1,2,1)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_ra_ind6days.dat').read()
data_ra = json.loads(f)

plt.hist(data_ra, bins = 100) 
plt.xlabel("RA position difference in arcsec")
plt.ylabel("# of sources")


plt.subplot(1,2,2)

f = open('/datadec/cppm/jpreyes/CFHT_Jointcal_2/dispersion_dec_ind6days.dat').read()
data_dec = json.loads(f)

plt.hist(data_dec, bins = 100) 
plt.xlabel("Dec position difference in arcsec")
plt.ylabel("# of sources")
#plt.ticklabel_format(style='sci', axis='x',scilimits=(0,0))

plt.show()

# %%
dists= np.sqrt(np.power(data_ra,2)+np.power(data_dec,2))

plt.hist(dists, bins = 100) 
plt.xlabel("position difference in arcsec")
plt.ylabel("# of sources")
