# %%
from lsst.pipe.tasks.sourceClassification import SourceClassificationTask
# Out:
# /renoir_data_00/fouchez/lsst/DM/stacks/lsstsw/2016-04-04/lsstsw/miniconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# here

# %%
text = "/renoir_data_02/jpreyes/lsst_data/CFHTLS_master/output/ --output /renoir_data_02/jpreyes/lsst_data/CFHTLS_master/output --id visit=837002 ccd=14..15 filter=r --clobber-config -j 56 -t 999999"
params = text.split(" ")

# %%
res = SourceClassificationTask.parseAndRun(params, doReturnResults=True)
# Out:
# initialization 2
# initialization 2
# initialization 2
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# ...

# %%
len(res.resultList)
# Out:
# 2

# %%
res
keys = res.getDict().keys()
print keys
# Out:
# ['taskRunner', 'parsedCmd', 'resultList', 'argumentParser']

# %%
tr = res.taskRunner

# %%
s = tr.run(res.parsedCmd)
# Out:
# initialization 2
# initialization 2
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# float division by zero
# ...

# %%
print s
# Out:
# [None]
